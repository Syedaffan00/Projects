# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\wasiq\\Downloads\\TCS1.csv")

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2004-08-27   122.800003   122.800003   119.820000   120.332497
# 1     2004-08-30   121.237503   123.750000   120.625000   123.345001
# 2     2004-08-31   123.312500   123.750000   122.000000   123.512497
# 3     2004-09-01   123.750000   124.375000   122.949997   123.487503
# 4     2004-09-02   123.737503   125.574997   123.250000   124.207497
# ...          ...          ...          ...          ...          ...
# 4489  2022-10-18  3150.000000  3155.350098  3128.550049  3144.699951
# 4490  2022-10-19  3159.000000  3159.000000  3112.000000  3121.850098
# 4491  2022-10-20  3105.000000  3160.000000  3105.000000  3157.300049
# 4492  2022-10-21  3157.800049  3160.399902  3127.000000  3137.399902
# 4493  2022-10-24  3170.100098  3178.000000  3155.000000  3161.699951
#
#         Adj Close      Volume
# 0       88.088272  30646000.0
# 1       90.293549  24465208.0
# 2       90.416122  21194656.0
# 3       90.397820  19935544.0
# 4       90.924896  21356352.0
# ...           ...         ...
# 4489  3144.699951   1793722.0
# 4490  3121.850098   1194289.0
# 4491  3157.300049   1587601.0
# 4492  3137.399902   1021913.0
# 4493  3161.699951    260949.0
#
# [4494 rows x 7 columns]

# %%
print(df.head())
# Out:
#          Date        Open        High         Low       Close  Adj Close  \
# 0  2004-08-27  122.800003  122.800003  119.820000  120.332497  88.088272
# 1  2004-08-30  121.237503  123.750000  120.625000  123.345001  90.293549
# 2  2004-08-31  123.312500  123.750000  122.000000  123.512497  90.416122
# 3  2004-09-01  123.750000  124.375000  122.949997  123.487503  90.397820
# 4  2004-09-02  123.737503  125.574997  123.250000  124.207497  90.924896
#
#        Volume
# 0  30646000.0
# 1  24465208.0
# 2  21194656.0
# 3  19935544.0
# 4  21356352.0

# %%
print(df.describe())
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4486.000000  4486.000000  4486.000000  4486.000000  4486.000000
# mean   1146.182768  1158.538059  1132.825428  1145.521462  1049.456965
# std     994.070086  1003.010607   984.043404   993.346465   992.062558
# min     112.000000   116.112503   103.837502   111.550003    86.565590
# 25%     290.693748   295.300010   285.931259   290.275009   219.902748
# 50%     977.450012   995.000000   970.250000   981.337524   820.627839
# 75%    1564.774963  1597.287476  1548.662537  1576.781219  1443.631561
# max    4033.949951  4043.000000  3980.000000  4019.149902  3964.502686
#
#              Volume
# count  4.486000e+03
# mean   3.620596e+06
# std    3.162368e+06
# min    0.000000e+00
# 25%    1.942489e+06
# 50%    2.804749e+06
# 75%    4.297410e+06
# max    8.806715e+07

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4494 entries, 0 to 4493
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4494 non-null   object
#  1   Open       4486 non-null   float64
#  2   High       4486 non-null   float64
#  3   Low        4486 non-null   float64
#  4   Close      4486 non-null   float64
#  5   Adj Close  4486 non-null   float64
#  6   Volume     4486 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 245.9+ KB
# None

# %%
df["Date"].value_counts()
# Out:
# 2004-08-27    1
# 2016-09-28    1
# 2016-10-06    1
# 2016-10-05    1
# 2016-10-04    1
#              ..
# 2010-09-20    1
# 2010-09-21    1
# 2010-09-22    1
# 2010-09-23    1
# 2022-10-24    1
# Name: Date, Length: 4494, dtype: int64

# %%
df['High'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
df.plot()
# Out:
# <AxesSubplot:>

# %%
dat=df.filter(['Close'])
dataset=df.values
training_data_length=math.ceil(len(df)*8)
training_data_length
dataset
# Out:
# array([['2004-08-27', 122.800003, 122.800003, ..., 120.332497, 88.088272,
#         30646000.0],
#        ['2004-08-30', 121.237503, 123.75, ..., 123.345001, 90.293549,
#         24465208.0],
#        ['2004-08-31', 123.3125, 123.75, ..., 123.512497, 90.416122,
#         21194656.0],
#        ...,
#        ['2022-10-20', 3105.0, 3160.0, ..., 3157.300049, 3157.300049,
#         1587601.0],
#        ['2022-10-21', 3157.800049, 3160.399902, ..., 3137.399902,
#         3137.399902, 1021913.0],
#        ['2022-10-24', 3170.100098, 3178.0, ..., 3161.699951, 3161.699951,
#         260949.0]], dtype=object)

# %%
df=df.iloc[:,0:5]
df
# Out:
#             Date         Open         High          Low        Close
# 0     2004-08-27   122.800003   122.800003   119.820000   120.332497
# 1     2004-08-30   121.237503   123.750000   120.625000   123.345001
# 2     2004-08-31   123.312500   123.750000   122.000000   123.512497
# 3     2004-09-01   123.750000   124.375000   122.949997   123.487503
# 4     2004-09-02   123.737503   125.574997   123.250000   124.207497
# ...          ...          ...          ...          ...          ...
# 4489  2022-10-18  3150.000000  3155.350098  3128.550049  3144.699951
# 4490  2022-10-19  3159.000000  3159.000000  3112.000000  3121.850098
# 4491  2022-10-20  3105.000000  3160.000000  3105.000000  3157.300049
# 4492  2022-10-21  3157.800049  3160.399902  3127.000000  3137.399902
# 4493  2022-10-24  3170.100098  3178.000000  3155.000000  3161.699951
#
# [4494 rows x 5 columns]

# %%
training_set=df.iloc[:,1:2].values 
training_set
# Out:
# array([[ 122.800003],
#        [ 121.237503],
#        [ 123.3125  ],
#        ...,
#        [3105.      ],
#        [3157.800049],
#        [3170.100098]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalar=MinMaxScaler(feature_range=(0,1))
data_training_scaled=scalar.fit_transform(training_set)

# %%
feature_set=[]
labels=[]
for i in range(60,586):
    feature_set.append(data_training_scaled[i-60:i,0])
    labels.append(data_training_scaled[i,0])

# %%
features_set,labels=np.array(feature_set),np.array(labels)

# %%
features_set=np.reshape(features_set,(features_set.shape[0],features_set.shape[1],1))
features_set.shape
# Out:
# (526, 60, 1)

# %%
import tensorflow
from keras.models import Sequential 
from keras.layers import LSTM,Dense

# %%
model=Sequential()
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
model.fit(features_set,labels,epochs=50,batch_size=20)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 2/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 3/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 4/50
# 27/27 [==============================] - 0s 3ms/step - loss: nan
# Epoch 5/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 7/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 8/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 9/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 11/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 12/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 16/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 17/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 18/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 20/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 21/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 22/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 23/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 24/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 25/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 27/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 28/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 29/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 30/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 31/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 32/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 33/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 34/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 35/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 36/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 37/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 38/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 39/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 40/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 41/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 42/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 43/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 44/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 45/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 46/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 47/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: nan
# Epoch 49/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan
# Epoch 50/50
# 27/27 [==============================] - 0s 1ms/step - loss: nan

# %%
data_testing_complete=pd.read_csv("C:\\Users\\wasiq\\Downloads\\TCS1.csv")
data_testing_processed=data_testing_complete.iloc[:,1:2]
data_testing_processed
# Out:
#              Open
# 0      122.800003
# 1      121.237503
# 2      123.312500
# 3      123.750000
# 4      123.737503
# ...           ...
# 4489  3150.000000
# 4490  3159.000000
# 4491  3105.000000
# 4492  3157.800049
# 4493  3170.100098
#
# [4494 rows x 1 columns]

# %%
data_total=pd.concat((df["Open"],df["Open"]),axis=0)

# %%
test_inputs=data_total[len(data_total)-len(df)-60:].values
test_inputs.shape
# Out:
# (4554,)

# %%
plt.figure(figsize=(18, 6))
plt.title("Stock market price prediction", fontsize=18)
plt.plot(data_testing_complete["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("No. of Trades", fontsize=16)
plt.show()

# %%
df["Date"]=pd.to_datetime(df.Date)
df.index=df["Date"]
plt.figure(figsize=(20,10))
plt.plot(df["Open"],label="ClosePriceHist")

# %%
plt.figure(figsize=(12,6))
plt.plot(df["Date"])
plt.xlabel("Total Turnover (Rs.)",fontsize=18)
plt.ylabel("No. of Trades",fontsize=18)
plt.show()

# %%
df["Total Turnover (Rs.)"]=pd.to_datetime(df.Date)
df.index=df["Total Turnover (Rs.)"]
plt.figure(figsize=(20,10))
plt.plot(df["Total Turnover (Rs.)"],label="ClosePriceHist")
